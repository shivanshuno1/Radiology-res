# %%
import pandas as pd
import numpy as np

# %%
train_file = pd.read_csv('train.csv')

# %%
train_file.iloc[1,:]
# Out:
# case_id                           218fc4a5-c7e9-44a7-9aea-54e56bb22663
# modality                                                          XRAY
# body_part                                                        Chest
# study_description                                            XR CXR 2V
# patient_age_band                                                 65-69
# patient_sex                                                       male
# template_content     FINDINGS:\nLUNGS: Lungs are clear. No focal ai...
# dictation            no effusuon, infiltrates\nmild thoracic spondy...
# report               FINDINGS:\nLUNGS: Lungs are clear. No focal ai...
# Name: 1, dtype: str
